# %% [markdown]
# Artificial Neural Network

# %% [markdown]
#  Classification

# %%
import tensorflow as tf
import pandas as pd
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import classification_report, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("https://raw.githubusercontent.com/aishwaryamate/Datasets/main/Classification.csv")
df
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited
# 0                  1        101348.88       1
# 1                  1        112542.58       0
# ...

# %%
x = df.iloc[:,:-1]
y = df["Exited"]

# %%
sc = StandardScaler()
x = sc.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 19)

# %%
# Initialize model
ann = Sequential()

#Add hidden layer
ann.add(Dense(units = 6, activation = "relu"))

#Add output layer
ann.add(Dense(units = 1, activation = "sigmoid"))

#Establish connection
ann.compile(optimizer = "adam", loss = "binary_crossentropy")

#Train the model
ann.fit(x_train, y_train, epochs = 50 )
# Out:
# Epoch 1/50
# 250/250 [==============================] - 2s 3ms/step - loss: 0.5872
# Epoch 2/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4741
# Epoch 3/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4442
# Epoch 4/50
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4334
# Epoch 5/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4269
# Epoch 6/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4214
# Epoch 7/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4166
# Epoch 8/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4118
# Epoch 9/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4074
# Epoch 10/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4028
# Epoch 11/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3984
# Epoch 12/50
# ...

# %%
ypred = ann.predict(x_test)
ypred = ypred>0.5
ypred
# Out:
# 63/63 [==============================] - 0s 2ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [ True]])

# %%
print(classification_report(y_test, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      1597
#            1       0.79      0.41      0.54       403
#
#     accuracy                           0.86      2000
#    macro avg       0.83      0.69      0.73      2000
# weighted avg       0.85      0.86      0.84      2000

# %%
re = pd.read_csv("https://raw.githubusercontent.com/aishwaryamate/Datasets/main/Regression.csv")
re
# Out:
#           price     feature1     feature2
# 0    461.527929   999.787558   999.766096
# 1    548.130012   998.861615  1001.042403
# 2    410.297162  1000.070267   998.844015
# 3    540.382220   999.952251  1000.440940
# 4    546.024553  1000.446011  1000.338531
# ..          ...          ...          ...
# 995  476.526078  1000.018988   999.672732
# 996  457.313186   998.855379  1000.020026
# 997  456.720993  1001.451646   998.847605
# 998  403.315576  1000.771023   998.562851
# 999  599.367094   999.232244  1001.451407
#
# [1000 rows x 3 columns]

# %%
X = re.iloc[:, 1:]
Y = re["price"]

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X,Y, test_size = 0.22, random_state = 10)

# %%
rnn = Sequential()
rnn.add(Dense(units = 30, activation = "relu"))
rnn.add(Dense(units = 19, activation = "relu"))
rnn.add(Dense(units = 1))
rnn.compile(optimizer = "adam", loss = "mse")
rnn.fit(Xtrain, Ytrain, epochs = 105)
# Out:
# Epoch 1/105
# 25/25 [==============================] - 1s 2ms/step - loss: 310869.3438
# Epoch 2/105
# 25/25 [==============================] - 0s 3ms/step - loss: 112957.5156
# Epoch 3/105
# 25/25 [==============================] - 0s 2ms/step - loss: 28988.5723
# Epoch 4/105
# 25/25 [==============================] - 0s 2ms/step - loss: 9363.6826
# Epoch 5/105
# 25/25 [==============================] - 0s 2ms/step - loss: 8695.9961
# Epoch 6/105
# 25/25 [==============================] - 0s 2ms/step - loss: 8687.7354
# Epoch 7/105
# 25/25 [==============================] - 0s 2ms/step - loss: 8670.1982
# Epoch 8/105
# 25/25 [==============================] - 0s 2ms/step - loss: 8676.3369
# Epoch 9/105
# 25/25 [==============================] - 0s 2ms/step - loss: 8665.5410
# Epoch 10/105
# 25/25 [==============================] - 0s 2ms/step - loss: 8683.6826
# Epoch 11/105
# 25/25 [==============================] - 0s 2ms/step - loss: 8674.0322
# Epoch 12/105
# ...

# %%
y_pred = rnn.predict(Xtest)
y_pred
# Out:
# 7/7 [==============================] - 0s 4ms/step
# array([[499.94226],
#        [500.2012 ],
#        [500.4211 ],
#        [500.45596],
#        [499.5538 ],
#        [500.54474],
#        [499.77274],
#        [500.4695 ],
#        [500.00552],
#        [499.57236],
#        [500.25095],
#        [499.94034],
#        [499.31674],
#        [500.03796],
#        [500.25528],
#        [499.94614],
#        [500.54745],
#        [500.50537],
#        [500.65762],
#        [499.6362 ],
#        [499.4301 ],
#        [500.59262],
#        [500.01126],
#        [499.79495],
#        [499.48727],
#        [499.88217],
#        [499.96597],
#        [499.71957],
#        [500.12314],
#        [500.5726 ],
#        [500.10367],
#        [499.89194],
#        [499.85513],
#        [500.2238 ],
#        [499.95926],
#        [500.67404],
#        [500.23535],
#        [500.5571 ],
#        [499.6558 ],
#        [500.0239 ],
#        [499.9681 ],
#        [500.0588 ],
#        [500.0883 ],
# ...

# %%
print(r2_score(Ytest, y_pred))
# Out:
# 0.0069521815570476875
